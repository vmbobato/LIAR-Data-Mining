# %% [markdown]
# # Data Validation
# Validate outputs from `01_prepare_liar.py`.

# %%
import pandas as pd
from pathlib import Path
base_path = Path('../data/processed/liar_base.parquet')
df = pd.read_parquet(base_path)
df.shape
# Out:
# (12791, 23)

# %%
df[['split','label','is_low_truth','party_grouped','state_clean']].head()
# Out:
#    split        label  is_low_truth party_grouped state_clean
# 0  train        false             1    republican       Texas
# 1  train    half-true             0      democrat    Virginia
# 2  train  mostly-true             0      democrat    Illinois
# 3  train        false             1       unknown     Unknown
# 4  train    half-true             0      democrat     Florida

# %%
df.groupby('split').size(), df['label'].value_counts()
# Out:
# (split
#  test      1267
#  train    10240
#  valid     1284
#  dtype: int64,
#  label
#  half-true      2627
#  false          2507
#  mostly-true    2454
#  barely-true    2103
#  true           2053
#  pants-fire     1047
#  Name: count, dtype: int64)
